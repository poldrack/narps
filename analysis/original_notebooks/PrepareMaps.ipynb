# %% [markdown]
# ### Prepare maps for analysis
#
# #### Hypotheses:
#
# Parametric effect of gain:
#
# 1. Positive effect in ventromedial PFC - for the equal indifference group
# 2. Positive effect in ventromedial PFC - for the equal range group
# 3. Positive effect in ventral striatum - for the equal indifference group
# 4. Positive effect in ventral striatum - for the equal range group
#
# Parametric effect of loss:
# - 5: Negative effect in VMPFC - for the equal indifference group
# - 6: Negative effect in VMPFC - for the equal range group
# - 7: Positive effect in amygdala - for the equal indifference group
# - 8: Positive effect in amygdala - for the equal range group
#
# Equal range vs. equal indifference:
#
# - 9: Greater positive response to losses in amygdala for equal range condition vs. equal indifference condition.
#
# #### Notes on data
#
# Data and hypothesis decisions were obtained from 70 teams.  Of these, the maps for 16 teams were excluded from further analysis due to the following problems:
#
# ##### Bad normalization/resampling:
#
# - SVXXBBHN_98BT: rejected due to very bad normalization
# - UGXECSGG_L1A8: resampled image much smaller than template brain
# - VDOVGCPL_4SZ2: resampled image offset from template brain
# - WBTVHMSS_4TQ6: resampled image  offset and too large compared to template
#
#
# ##### Missing thresholded images:
#
# - WIYTWEEA_2T7P: missing thresholded images
#
#
# ##### Used surface-based analysis (only provided data for cortical ribbon:
#
# - DRVQPPNO_1K0E
# - UMSEIVRB_X1Z4
#
#
# ##### Missing data:
#
# - YWGVKXBZ_6FH5: missing much of the central brain
# - ACMKXFTG_P5F3: rejected due to large amounts of missing data across brain
# - NNUNPWLT_0H5E: rejected due to large amount of missing brain in center
# - CMJIFMMR_L3V8: rejected due to large amount of missing brain in center
#
#
# ##### Bad histograms:
# visual examiniation of histograms of unthresholded images showed a number of them that were clearly not distribted as z/t
#
# - RIIVGRDK_E3B6: very long tail, with substantial inflation at a value just below zero
# - JAWCZRDS_V55J: very small values
# - EPBGXICO_I07H: bimodal, with second distribution centered around 2.5
# - UXJVRRRR_0C7Q: appears to be a p-value distribution, with slight excursions below and above zero
# - OXLAIRNK_Q58J: bimodal, zero-inflated with a second distribution centered around 5

# %%
# all of the functionality is now embedded in the Narps() class within narps.py
import os,sys,glob,warnings
import matplotlib.pyplot as plt
import numpy,pandas
import nilearn.input_data

from narps import Narps
from utils import get_masked_data,get_merged_metadata_decisions

overwrite = False
make_reports = False # turn on to generate individual maps - this takes a long time!
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# set an environment variable called NARPS_BASEDIR with location of base directory
if 'NARPS_BASEDIR' in os.environ:
    basedir = os.environ['NARPS_BASEDIR']
else:
    basedir = '/data'
assert os.path.exists(basedir)

metadata_dir = os.path.join(basedir,'metadata')
if not os.path.exists(metadata_dir):
    os.mkdir(metadata_dir)
    
# instantiate main Narps class, which loads data
# to rerun everything, set overwrite to True

narps = Narps(basedir,overwrite=overwrite)

output_dir = narps.dirs.dirs['output']
mask_img = narps.dirs.MNI_mask
# Out:
# found 54 input directories
# found 54 teams with complete original datasets

# %%
# uncomment to load cached data

# narps.load_data()

# %% [markdown]
# ### Create binarized thresholded masks
#
# load the thresholded maps and binarize the absolute value (to detect either positive or negative signals).  save output to the *thresh_mask_orig* directory (in original space).

# %%
narps.get_binarized_thresh_masks()

# %% [markdown]
# ### Resample images
#
# The images were supposed to be submitted in MNI space.  Here we use nilearn.image.resample_to_img() to resample the image into the FSL MNI space (91x109x91, 2mm isotropic).  For unthresholded maps, we use continuous interpolation; for thresholded maps, we use linear interpolation and then threshold at 0.5; this avoids some errors that occurred using nearest neighbor interpolation, where there were empty voxels in some slices. save to *resampled* directory.

# %%
narps.get_resampled_images()
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater
# <string>:1: RuntimeWarning: invalid value encountered in greater

# %% [markdown]
# ### Check image values
#
# Compute number of NA and zero voxels for each image, and save to image_metadata_df.csv.

# %%
image_value_df = narps.check_image_values()

# %% [markdown]
# ### Combine resampled images for thresholded data
#
# Combine all images into a single concatenated file for each hypothesis.  save to *thresh\_concat\_resampled*.

# %%
_ = narps.create_concat_images(datatype='resampled',imgtypes = ['thresh'],overwrite=overwrite)

# %% [markdown]
# ### Create overlap images for thresholded maps

# %%
narps.create_thresh_overlap_images()

# %% [markdown]
# ### Rectify maps
#
# Rectify the unthresholded maps if they used positive values for negative activations - so that all unthresholded maps reflect positive values for the hypothesis in question.  This is based on metadata provided by each team. Save to *rectified*

# %%
narps.create_rectified_images()
# Out:
# rectifying hyp 5 for 0JO0
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 0JO0
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 16IN
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for 2T6S
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 2T6S
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for 46CD
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 46CD
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for 5G9K
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 5G9K
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for 6VV2
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 6VV2
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for 80GC
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 80GC
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for 9U7M
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for 9U7M
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for AO86
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for AO86
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for B23O
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for B23O
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for E6R3
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for E6R3
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for I52Y
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for I52Y
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for I9D6
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for I9D6
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for K9P0
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for K9P0
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for L7J7
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for L7J7
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for L9G5
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for L9G5
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for O03M
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for O03M
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for R42Q
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for R42Q
# Negative values in the images represent negative activation
#
# rectifying hyp 9 for R7D1
# Positive values represent equal indifference > equal range; Negative values represent equal range > equal indifference
#
# rectifying hyp 5 for SM54
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for SM54
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for U26C
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for U26C
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for UI76
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for UI76
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for UK24
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for UK24
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for VG39
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for VG39
# Negative values in the images represent negative activation
#
# rectifying hyp 5 for X19V
# Negative values in the images represent negative activation
#
# rectifying hyp 6 for X19V
# Negative values in the images represent negative activation

# %% [markdown]
# ### Create concatenated rectified unthresholded images

# %%
# concat_rectified = narps.create_concat_images(datatype='rectified',imgtypes = ['unthresh'],overwrite=True)

# %% [markdown]
# ### Convert all unthresholded images to Z stat images
#
# Use metadata reported by teams (contained in NARPS_analysis_teams_members.csv) which specifies what kind of unthresholded statistical images were submitted.  For those who reported T values, convert those to Z values using Hughett's transform (based on https://github.com/vsoch/TtoZ/blob/master/TtoZ/scripts.py)

# %%
narps.convert_to_zscores()
# Out:
# converting 08MQ (hyp 1) to z - 106 participants
# converting 08MQ (hyp 2) to z - 106 participants
# converting 08MQ (hyp 3) to z - 106 participants
# converting 08MQ (hyp 4) to z - 106 participants
# converting 08MQ (hyp 5) to z - 106 participants
# converting 08MQ (hyp 6) to z - 106 participants
# converting 08MQ (hyp 7) to z - 106 participants
# converting 08MQ (hyp 8) to z - 106 participants
# converting 08MQ (hyp 9) to z - 106 participants
# converting 0ED6 (hyp 1) to z - 108 participants
# converting 0ED6 (hyp 2) to z - 108 participants
# converting 0ED6 (hyp 3) to z - 108 participants
# converting 0ED6 (hyp 4) to z - 108 participants
# converting 0ED6 (hyp 5) to z - 108 participants
# converting 0ED6 (hyp 6) to z - 108 participants
# converting 0ED6 (hyp 7) to z - 108 participants
# converting 0ED6 (hyp 8) to z - 108 participants
# converting 0ED6 (hyp 9) to z - 108 participants
# converting 0I4U (hyp 1) to z - 108 participants
# converting 0I4U (hyp 2) to z - 108 participants
# converting 0I4U (hyp 3) to z - 108 participants
# converting 0I4U (hyp 4) to z - 108 participants
# converting 0I4U (hyp 5) to z - 108 participants
# converting 0I4U (hyp 6) to z - 108 participants
# converting 0I4U (hyp 7) to z - 108 participants
# converting 0I4U (hyp 8) to z - 108 participants
# converting 0I4U (hyp 9) to z - 108 participants
# copying 0JO0
# copying 0JO0
# copying 0JO0
# copying 0JO0
# copying 0JO0
# copying 0JO0
# copying 0JO0
# copying 0JO0
# copying 0JO0
# skipping 16IN - other data type
# skipping 16IN - other data type
# skipping 16IN - other data type
# skipping 16IN - other data type
# skipping 16IN - other data type
# skipping 16IN - other data type
# skipping 16IN - other data type
# skipping 16IN - other data type
# skipping 16IN - other data type
# copying 1KB2
# copying 1KB2
# copying 1KB2
# copying 1KB2
# copying 1KB2
# copying 1KB2
# copying 1KB2
# copying 1KB2
# copying 1KB2
# converting 1P0Y (hyp 1) to z - 104 participants
# converting 1P0Y (hyp 2) to z - 104 participants
# converting 1P0Y (hyp 3) to z - 104 participants
# converting 1P0Y (hyp 4) to z - 104 participants
# converting 1P0Y (hyp 5) to z - 104 participants
# converting 1P0Y (hyp 6) to z - 104 participants
# converting 1P0Y (hyp 7) to z - 104 participants
# converting 1P0Y (hyp 8) to z - 104 participants
# converting 1P0Y (hyp 9) to z - 104 participants
# converting 27SS (hyp 1) to z - 108 participants
# converting 27SS (hyp 2) to z - 108 participants
# converting 27SS (hyp 3) to z - 108 participants
# converting 27SS (hyp 4) to z - 108 participants
# converting 27SS (hyp 5) to z - 108 participants
# converting 27SS (hyp 6) to z - 108 participants
# converting 27SS (hyp 7) to z - 108 participants
# converting 27SS (hyp 8) to z - 108 participants
# converting 27SS (hyp 9) to z - 108 participants
# converting 2T6S (hyp 1) to z - 108 participants
# converting 2T6S (hyp 2) to z - 108 participants
# converting 2T6S (hyp 3) to z - 108 participants
# converting 2T6S (hyp 4) to z - 108 participants
# converting 2T6S (hyp 5) to z - 108 participants
# converting 2T6S (hyp 6) to z - 108 participants
# converting 2T6S (hyp 7) to z - 108 participants
# converting 2T6S (hyp 8) to z - 108 participants
# converting 2T6S (hyp 9) to z - 108 participants
# converting 3C6G (hyp 1) to z - 107 participants
# converting 3C6G (hyp 2) to z - 107 participants
# converting 3C6G (hyp 3) to z - 107 participants
# converting 3C6G (hyp 4) to z - 107 participants
# converting 3C6G (hyp 5) to z - 107 participants
# converting 3C6G (hyp 6) to z - 107 participants
# converting 3C6G (hyp 7) to z - 107 participants
# converting 3C6G (hyp 8) to z - 107 participants
# converting 3C6G (hyp 9) to z - 107 participants
# copying 3PQ2
# copying 3PQ2
# copying 3PQ2
# copying 3PQ2
# copying 3PQ2
# copying 3PQ2
# copying 3PQ2
# copying 3PQ2
# copying 3PQ2
# converting 3TR7 (hyp 1) to z - 108 participants
# converting 3TR7 (hyp 2) to z - 108 participants
# converting 3TR7 (hyp 3) to z - 108 participants
# converting 3TR7 (hyp 4) to z - 108 participants
# converting 3TR7 (hyp 5) to z - 108 participants
# converting 3TR7 (hyp 6) to z - 108 participants
# converting 3TR7 (hyp 7) to z - 108 participants
# converting 3TR7 (hyp 8) to z - 108 participants
# converting 3TR7 (hyp 9) to z - 108 participants
# copying 43FJ
# copying 43FJ
# copying 43FJ
# copying 43FJ
# copying 43FJ
# copying 43FJ
# copying 43FJ
# copying 43FJ
# copying 43FJ
# converting 46CD (hyp 1) to z - 105 participants
# converting 46CD (hyp 2) to z - 105 participants
# converting 46CD (hyp 3) to z - 105 participants
# converting 46CD (hyp 4) to z - 105 participants
# converting 46CD (hyp 5) to z - 105 participants
# converting 46CD (hyp 6) to z - 105 participants
# converting 46CD (hyp 7) to z - 105 participants
# converting 46CD (hyp 8) to z - 105 participants
# converting 46CD (hyp 9) to z - 105 participants
# copying 50GV
# copying 50GV
# copying 50GV
# copying 50GV
# copying 50GV
# copying 50GV
# copying 50GV
# copying 50GV
# copying 50GV
# copying 51PW
# copying 51PW
# copying 51PW
# copying 51PW
# copying 51PW
# copying 51PW
# copying 51PW
# copying 51PW
# copying 51PW
# converting 5G9K (hyp 1) to z - 88 participants
# /analysis/utils.py:156: RuntimeWarning: invalid value encountered in less_equal
#   k1 = (nonzero <= c)
# /analysis/utils.py:157: RuntimeWarning: invalid value encountered in greater
#   k2 = (nonzero > c)
# converting 5G9K (hyp 2) to z - 88 participants
# converting 5G9K (hyp 3) to z - 88 participants
# converting 5G9K (hyp 4) to z - 88 participants
# converting 5G9K (hyp 5) to z - 88 participants
# converting 5G9K (hyp 6) to z - 88 participants
# converting 5G9K (hyp 7) to z - 88 participants
# converting 5G9K (hyp 8) to z - 88 participants
# converting 5G9K (hyp 9) to z - 88 participants
# copying 6VV2
# copying 6VV2
# copying 6VV2
# copying 6VV2
# copying 6VV2
# copying 6VV2
# copying 6VV2
# copying 6VV2
# copying 6VV2
# copying 80GC
# copying 80GC
# copying 80GC
# copying 80GC
# copying 80GC
# copying 80GC
# copying 80GC
# copying 80GC
# copying 80GC
# converting 94GU (hyp 1) to z - 108 participants
# converting 94GU (hyp 2) to z - 108 participants
# converting 94GU (hyp 3) to z - 108 participants
# converting 94GU (hyp 4) to z - 108 participants
# converting 94GU (hyp 5) to z - 108 participants
# converting 94GU (hyp 6) to z - 108 participants
# converting 94GU (hyp 7) to z - 108 participants
# converting 94GU (hyp 8) to z - 108 participants
# converting 94GU (hyp 9) to z - 108 participants
# copying 9Q6R
# copying 9Q6R
# copying 9Q6R
# copying 9Q6R
# copying 9Q6R
# copying 9Q6R
# copying 9Q6R
# copying 9Q6R
# copying 9Q6R
# converting 9T8E (hyp 1) to z - 106 participants
# converting 9T8E (hyp 2) to z - 106 participants
# converting 9T8E (hyp 3) to z - 106 participants
# converting 9T8E (hyp 4) to z - 106 participants
# converting 9T8E (hyp 5) to z - 106 participants
# converting 9T8E (hyp 6) to z - 106 participants
# converting 9T8E (hyp 7) to z - 106 participants
# converting 9T8E (hyp 8) to z - 106 participants
# converting 9T8E (hyp 9) to z - 106 participants
# copying 9U7M
# copying 9U7M
# copying 9U7M
# copying 9U7M
# copying 9U7M
# copying 9U7M
# copying 9U7M
# copying 9U7M
# copying 9U7M
# converting AO86 (hyp 1) to z - 108 participants
# converting AO86 (hyp 2) to z - 108 participants
# converting AO86 (hyp 3) to z - 108 participants
# converting AO86 (hyp 4) to z - 108 participants
# converting AO86 (hyp 5) to z - 108 participants
# converting AO86 (hyp 6) to z - 108 participants
# converting AO86 (hyp 7) to z - 108 participants
# converting AO86 (hyp 8) to z - 108 participants
# converting AO86 (hyp 9) to z - 108 participants
# converting B23O (hyp 1) to z - 108 participants
# converting B23O (hyp 2) to z - 108 participants
# converting B23O (hyp 3) to z - 108 participants
# converting B23O (hyp 4) to z - 108 participants
# converting B23O (hyp 5) to z - 108 participants
# converting B23O (hyp 6) to z - 108 participants
# converting B23O (hyp 7) to z - 108 participants
# converting B23O (hyp 8) to z - 108 participants
# converting B23O (hyp 9) to z - 108 participants
# converting B5I6 (hyp 1) to z - 106 participants
# converting B5I6 (hyp 2) to z - 106 participants
# converting B5I6 (hyp 3) to z - 106 participants
# converting B5I6 (hyp 4) to z - 106 participants
# converting B5I6 (hyp 5) to z - 106 participants
# converting B5I6 (hyp 6) to z - 106 participants
# converting B5I6 (hyp 7) to z - 106 participants
# converting B5I6 (hyp 8) to z - 106 participants
# converting B5I6 (hyp 9) to z - 106 participants
# copying C22U
# copying C22U
# copying C22U
# copying C22U
# copying C22U
# copying C22U
# copying C22U
# copying C22U
# copying C22U
# converting C88N (hyp 1) to z - 106 participants
# converting C88N (hyp 2) to z - 106 participants
# converting C88N (hyp 3) to z - 106 participants
# converting C88N (hyp 4) to z - 106 participants
# converting C88N (hyp 5) to z - 106 participants
# converting C88N (hyp 6) to z - 106 participants
# converting C88N (hyp 7) to z - 106 participants
# converting C88N (hyp 8) to z - 106 participants
# converting C88N (hyp 9) to z - 106 participants
# converting DC61 (hyp 1) to z - 105 participants
# converting DC61 (hyp 2) to z - 105 participants
# converting DC61 (hyp 3) to z - 105 participants
# converting DC61 (hyp 4) to z - 105 participants
# converting DC61 (hyp 5) to z - 105 participants
# converting DC61 (hyp 6) to z - 105 participants
# converting DC61 (hyp 7) to z - 105 participants
# converting DC61 (hyp 8) to z - 105 participants
# converting DC61 (hyp 9) to z - 105 participants
# converting E6R3 (hyp 1) to z - 108 participants
# converting E6R3 (hyp 2) to z - 108 participants
# converting E6R3 (hyp 3) to z - 108 participants
# converting E6R3 (hyp 4) to z - 108 participants
# converting E6R3 (hyp 5) to z - 108 participants
# converting E6R3 (hyp 6) to z - 108 participants
# converting E6R3 (hyp 7) to z - 108 participants
# converting E6R3 (hyp 8) to z - 108 participants
# converting E6R3 (hyp 9) to z - 108 participants
# converting I52Y (hyp 1) to z - 106 participants
# converting I52Y (hyp 2) to z - 106 participants
# converting I52Y (hyp 3) to z - 106 participants
# converting I52Y (hyp 4) to z - 106 participants
# converting I52Y (hyp 5) to z - 106 participants
# converting I52Y (hyp 6) to z - 106 participants
# converting I52Y (hyp 7) to z - 106 participants
# converting I52Y (hyp 8) to z - 106 participants
# converting I52Y (hyp 9) to z - 106 participants
# copying I9D6
# copying I9D6
# copying I9D6
# copying I9D6
# copying I9D6
# copying I9D6
# copying I9D6
# copying I9D6
# copying I9D6
# converting IZ20 (hyp 1) to z - 108 participants
# converting IZ20 (hyp 2) to z - 108 participants
# converting IZ20 (hyp 3) to z - 108 participants
# converting IZ20 (hyp 4) to z - 108 participants
# converting IZ20 (hyp 5) to z - 108 participants
# converting IZ20 (hyp 6) to z - 108 participants
# converting IZ20 (hyp 7) to z - 108 participants
# converting IZ20 (hyp 8) to z - 108 participants
# converting IZ20 (hyp 9) to z - 108 participants
# converting J7F9 (hyp 1) to z - 107 participants
# converting J7F9 (hyp 2) to z - 107 participants
# converting J7F9 (hyp 3) to z - 107 participants
# converting J7F9 (hyp 4) to z - 107 participants
# converting J7F9 (hyp 5) to z - 107 participants
# converting J7F9 (hyp 6) to z - 107 participants
# converting J7F9 (hyp 7) to z - 107 participants
# converting J7F9 (hyp 8) to z - 107 participants
# converting J7F9 (hyp 9) to z - 107 participants
# converting K9P0 (hyp 1) to z - 107 participants
# converting K9P0 (hyp 2) to z - 107 participants
# converting K9P0 (hyp 3) to z - 107 participants
# converting K9P0 (hyp 4) to z - 107 participants
# converting K9P0 (hyp 5) to z - 107 participants
# converting K9P0 (hyp 6) to z - 107 participants
# converting K9P0 (hyp 7) to z - 107 participants
# converting K9P0 (hyp 8) to z - 107 participants
# converting K9P0 (hyp 9) to z - 107 participants
# converting L7J7 (hyp 1) to z - 108 participants
# converting L7J7 (hyp 2) to z - 108 participants
# converting L7J7 (hyp 3) to z - 108 participants
# converting L7J7 (hyp 4) to z - 108 participants
# converting L7J7 (hyp 5) to z - 108 participants
# converting L7J7 (hyp 6) to z - 108 participants
# converting L7J7 (hyp 7) to z - 108 participants
# converting L7J7 (hyp 8) to z - 108 participants
# converting L7J7 (hyp 9) to z - 108 participants
# copying L9G5
# copying L9G5
# copying L9G5
# copying L9G5
# copying L9G5
# copying L9G5
# copying L9G5
# copying L9G5
# copying L9G5
# copying O03M
# copying O03M
# copying O03M
# copying O03M
# copying O03M
# copying O03M
# copying O03M
# copying O03M
# copying O03M
# copying O21U
# copying O21U
# copying O21U
# copying O21U
# copying O21U
# copying O21U
# copying O21U
# copying O21U
# copying O21U
# converting O6R6 (hyp 1) to z - 108 participants
# converting O6R6 (hyp 2) to z - 108 participants
# converting O6R6 (hyp 3) to z - 108 participants
# converting O6R6 (hyp 4) to z - 108 participants
# converting O6R6 (hyp 5) to z - 108 participants
# converting O6R6 (hyp 6) to z - 108 participants
# converting O6R6 (hyp 7) to z - 108 participants
# converting O6R6 (hyp 8) to z - 108 participants
# converting O6R6 (hyp 9) to z - 108 participants
# converting Q6O0 (hyp 1) to z - 107 participants
# converting Q6O0 (hyp 2) to z - 107 participants
# converting Q6O0 (hyp 3) to z - 107 participants
# converting Q6O0 (hyp 4) to z - 107 participants
# converting Q6O0 (hyp 5) to z - 107 participants
# converting Q6O0 (hyp 6) to z - 107 participants
# converting Q6O0 (hyp 7) to z - 107 participants
# converting Q6O0 (hyp 8) to z - 107 participants
# converting Q6O0 (hyp 9) to z - 107 participants
# copying R42Q
# copying R42Q
# copying R42Q
# copying R42Q
# copying R42Q
# copying R42Q
# copying R42Q
# copying R42Q
# copying R42Q
# converting R5K7 (hyp 1) to z - 108 participants
# converting R5K7 (hyp 2) to z - 108 participants
# converting R5K7 (hyp 3) to z - 108 participants
# converting R5K7 (hyp 4) to z - 108 participants
# converting R5K7 (hyp 5) to z - 108 participants
# converting R5K7 (hyp 6) to z - 108 participants
# converting R5K7 (hyp 7) to z - 108 participants
# converting R5K7 (hyp 8) to z - 108 participants
# converting R5K7 (hyp 9) to z - 108 participants
# converting R7D1 (hyp 1) to z - 107 participants
# converting R7D1 (hyp 2) to z - 107 participants
# converting R7D1 (hyp 3) to z - 107 participants
# converting R7D1 (hyp 4) to z - 107 participants
# converting R7D1 (hyp 5) to z - 107 participants
# converting R7D1 (hyp 6) to z - 107 participants
# converting R7D1 (hyp 7) to z - 107 participants
# converting R7D1 (hyp 8) to z - 107 participants
# converting R7D1 (hyp 9) to z - 107 participants
# converting R9K3 (hyp 1) to z - 102 participants
# converting R9K3 (hyp 2) to z - 102 participants
# converting R9K3 (hyp 3) to z - 102 participants
# converting R9K3 (hyp 4) to z - 102 participants
# converting R9K3 (hyp 5) to z - 102 participants
# converting R9K3 (hyp 6) to z - 102 participants
# converting R9K3 (hyp 7) to z - 102 participants
# converting R9K3 (hyp 8) to z - 102 participants
# converting R9K3 (hyp 9) to z - 102 participants
# copying SM54
# copying SM54
# copying SM54
# copying SM54
# copying SM54
# copying SM54
# copying SM54
# copying SM54
# copying SM54
# copying T54A
# copying T54A
# copying T54A
# copying T54A
# copying T54A
# copying T54A
# copying T54A
# copying T54A
# copying T54A
# converting U26C (hyp 1) to z - 108 participants
# converting U26C (hyp 2) to z - 108 participants
# converting U26C (hyp 3) to z - 108 participants
# converting U26C (hyp 4) to z - 108 participants
# converting U26C (hyp 5) to z - 108 participants
# converting U26C (hyp 6) to z - 108 participants
# converting U26C (hyp 7) to z - 108 participants
# converting U26C (hyp 8) to z - 108 participants
# converting U26C (hyp 9) to z - 108 participants
# copying UI76
# copying UI76
# copying UI76
# copying UI76
# copying UI76
# copying UI76
# copying UI76
# copying UI76
# copying UI76
# converting UK24 (hyp 1) to z - 107 participants
# converting UK24 (hyp 2) to z - 107 participants
# converting UK24 (hyp 3) to z - 107 participants
# converting UK24 (hyp 4) to z - 107 participants
# converting UK24 (hyp 5) to z - 107 participants
# converting UK24 (hyp 6) to z - 107 participants
# converting UK24 (hyp 7) to z - 107 participants
# converting UK24 (hyp 8) to z - 107 participants
# converting UK24 (hyp 9) to z - 107 participants
# copying VG39
# copying VG39
# copying VG39
# copying VG39
# copying VG39
# copying VG39
# copying VG39
# copying VG39
# copying VG39
# copying X19V
# copying X19V
# copying X19V
# copying X19V
# copying X19V
# copying X19V
# copying X19V
# copying X19V
# copying X19V
# converting X1Y5 (hyp 1) to z - 102 participants
# converting X1Y5 (hyp 2) to z - 102 participants
# converting X1Y5 (hyp 3) to z - 102 participants
# converting X1Y5 (hyp 4) to z - 102 participants
# converting X1Y5 (hyp 5) to z - 102 participants
# converting X1Y5 (hyp 6) to z - 102 participants
# converting X1Y5 (hyp 7) to z - 102 participants
# converting X1Y5 (hyp 8) to z - 102 participants
# converting X1Y5 (hyp 9) to z - 102 participants
# copying XU70
# copying XU70
# copying XU70
# copying XU70
# copying XU70
# copying XU70
# copying XU70
# copying XU70
# copying XU70

# %% [markdown]
# ### Create concatenated zstat images

# %%
concat_zstat = narps.create_concat_images(datatype='zstat',imgtypes = ['unthresh'],overwrite=True)

# %% [markdown]
# ### Compute image statistics
#
# Compute range and standard deviation maps across teams for zstat maps.

# %%
narps.compute_image_stats(overwrite=True)

# %% [markdown]
# ### Estimate smoothness
#
# Use FSL's SmoothEstimate (via nipype) to estimate smoothness of each Z map.

# %%
smoothness_df = narps.estimate_smoothness(overwrite=True)
# Out:
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo1_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo2_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo3_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo4_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo5_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo6_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo7_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo8_unthresh.nii.gz
# no image present: /data/maps/zstat/YBXXQPUZ_16IN/hypo9_unthresh.nii.gz

# %% [markdown]
# ### Save outputs
#
# Serialize the important information from the class and save to *narps_prepare_maps.pkl*

# %%
output = narps.write_data()

# %% [markdown]
# ## Make reports
#
# Create some diagnostic reports

# %% [markdown]
# ### Make report showing all orig maps with threshold overlays
#
# This report includes all maps for which data were available, including those that were excluded

# %%
if make_reports:
    cut_coords = [-24,-10,4,18,32,52,64]

    bins = numpy.linspace(-5,5)


    figdir = os.path.join(basedir,'figures/orig_map_overlays')

    if not os.path.exists(figdir):
        os.mkdir(figdir)


    for hyp in [1,2,5,6,7,8,9]:
        outfile = os.path.join(figdir,'hyp%d_orig_map_overlays.pdf'%hyp)

        if not os.path.exists(outfile) or overwrite:
            print('making map overlay figure for hyp',hyp)

            # find all maps
            hmaps = glob.glob(os.path.join(output_dir,'orig/*_*'))

            collection_ids = [os.path.basename(i) for i in hmaps]
            collection_ids.sort()

            fig, ax = plt.subplots(len(collection_ids),2,figsize=(len(collection_ids),140),gridspec_kw={'width_ratios': [2, 1]})
            ctr=0

            for collection_id in collection_ids:
                teamID = collection_id.split('_')[1]
                unthresh_img=os.path.join(output_dir,'orig/%s/hypo%d_unthresh.nii.gz'%(collection_id,hyp))
                thresh_img=os.path.join(output_dir,'thresh_mask_orig/%s/hypo%d_thresh.nii.gz'%(collection_id,hyp))

                if not (os.path.exists(thresh_img) or os.path.exists(unthresh_img)):
                    print('skipping',teamID)
                    continue

                if not teamID in narps.complete_image_sets:
                    imagetitle = '%s (excluded)'%teamID
                else:
                    imagetitle = teamID

                display = nilearn.plotting.plot_stat_map(unthresh_img, display_mode="z", 
                        colorbar=True,title=collection_id,
                                          cut_coords = cut_coords,axes = ax[ctr,0],cmap='gray')

                with warnings.catch_warnings():  # ignore levels warning
                    warnings.simplefilter("ignore")
                    display.add_contours(thresh_img, filled=False, alpha=0.7, levels=[0.5], colors='b') 

                masker=nilearn.input_data.NiftiMasker(mask_img=thresh_img)
                maskdata = masker.fit_transform(unthresh_img)
                if numpy.sum(maskdata)>0:  # check for empty mask
                    hist_result=ax[ctr,1].hist(maskdata,bins=bins)
                ctr+=1
            plt.savefig(outfile)
            plt.close(fig)

# %% [markdown]
# #### Create histograms for in-mask values in unthresholded images
#
# These are only created for the images that were successfully registered and rectified.

# %%
if make_reports:
    figdir = os.path.join(basedir,'figures/unthresh_histograms')

    if not os.path.exists(figdir):
        os.mkdir(figdir)

    for hyp in [1,2,5,6,7,8,9]:
        outfile = os.path.join(figdir,'hyp%d_unthresh_histogram.pdf'%hyp)

        if not os.path.exists(outfile) or overwrite:
            print('making figure for hyp',hyp)
            unthresh_data,labels=get_masked_data(hyp,mask_img,output_dir,imgtype='unthresh',dataset='rectified')
            fig, ax = plt.subplots(int(numpy.ceil(len(labels)/3)),3,figsize=(16,50))

            # make three columns - these are row and column counters
            ctr_x=0
            ctr_y=0

            for i,l in enumerate(labels):
                    ax[ctr_x,ctr_y].hist(unthresh_data[i,:],100)
                    ax[ctr_x,ctr_y].set_title(l)
                    ctr_y+=1
                    if ctr_y>2:
                        ctr_y=0
                        ctr_x+=1
            plt.tight_layout()

            plt.savefig(outfile)
